# %% [markdown]
# ## LESHI example workflow

# %% [markdown]
# Needed installations:

# %%
pip install numpy scipy opencv-python pandas emcee p_tqdm astropy spectral_cube matplotlib photutils wget astrocut

# %% [markdown]
# For the code to work, this notebook has to be in the same directory as the "LESHI" folder.

# %%
from LESHI import LESHI
import pandas as pd

# %% [markdown]
# we can print the LESHI function helper description:

# %%
help(LESHI.source_finder)
# Out:
# Help on function source_finder in module LESHI.LESHI:
#
# source_finder(data_cube, path_to_results, SNR_integ=3.5, SNR_channel=2.5, sig_min_le=3, sig_max_len=100, SNR_spec=3.5, rsqr_min=0.35, int_image_len=10, int_image_load_no=10, channel_start=0, channel_end=None, beam=None, test_hist=False, bg_box_size=100, max_dist_pix=10, max_dist_channel=10)
#     Start the LESHI Source Finder.
#
#     Parameters
#     ----------
#     data_file : str
#         Path to the datacube to perform source finding on.
#
#     path_to_results : str
#         Path to the directory where the results will be saved.
#
#     SNR_integ : int or float
#         Threshold signal-to-noise ratio of each source on the integrated image (default = 3.5)
#
#     SNR_channel : int or float
#         Threshold signal-to-noise ratio of each source on the channel image (default = 2.5)
#
#     SNR_spec : int or float
#         Threshold signal-to-noise ratio of each source on the spectrum (default = 3.5)
#
# ...

# %%
# let's call the sourcefinder
data_cube= '../../CARTA_cubes/mightee_cube_MIGHTEE-HI_DR1_COSMOS_L2_r0p5_clean_conv_3001-4055_Simulated_Cube_noise.fits'
LESHI.source_finder(data_cube, path_to_results,
                       SNR_integ=3.5, SNR_channel=2.5, 
                       channel_min_len=3,
                       channel_max_len=100,
                       SNR_spec=3.5, rsqr_min=0.35,
                       int_image_len=10, int_image_load_no=10,
                       channel_start=0, channel_end=None, beam=None, test_hist=False, 
                       bg_box_size=100, max_dist_pix=10, max_dist_channel=10 )

# %%
# for each detection we can quickly download optical images (curently the code works for 'HSC' and 'LegacySurvey')
# this requires the wget package to be installed (https://formulae.brew.sh/formula/wget)

data_table = pd.read_csv('./source_finding_results_1/found_sources_associated.csv')

ra_array = df['RA_deg'].values
dec_array = df['Dec_deg'].values
ID_array = df['ID'].values
filters = ['G','R','I']
LESHI.get_opt_cutout(ID=ID_array,ra=ra_array,dec=dec_array,width_arc=200,
                     filters=filters,survey='HSC',path_to_images='./optcial_images/')

# %%
# having optical images we can create detection plots showing the detection, spectrum and optical image 

LESHI.detection_plot(data_table = data_table, path_to_data_cube = data_cube, 
                     path_to_optical_images = './optcial_images/', path_to_results='./',
                   image_arc_width = 100, spectrum_length = 200, beam = None)

# %%
# we can go through all detections using the eye_checker window and flag each source quickly

LESHI.eye_check(data_table = data_table, path_to_figures = './detection_plots_1/', path_to_results = './')
